# %%
my_dict = {
    "fname": ["john",'anakin','tony'],
    "lname": ["zena",'vader','mackwi'],
    "age": [30,45,32],
    "is_student": [False,False,False],
    "grades": [90, 85, 88]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(my_dict)

# %%
df
# Out:
#     fname   lname  age  is_student  grades
# 0    john    zena   30       False      90
# 1  anakin   vader   45       False      85
# 2    tony  mackwi   32       False      88

# %%
df.sort_values(by="fname", ascending=False)
# Out:
#     fname   lname  age  is_student  grades
# 2    tony  mackwi   32       False      88
# 0    john    zena   30       False      90
# 1  anakin   vader   45       False      85

# %%
df.sort_values(by=["fname",'lname'], ascending=False)
# Out:
#     fname   lname  age  is_student  grades
# 2    tony  mackwi   32       False      88
# 0    john    zena   30       False      90
# 1  anakin   vader   45       False      85

# %%
df.sort_index()
# Out:
#     fname   lname  age  is_student  grades
# 0    john    zena   30       False      90
# 1  anakin   vader   45       False      85
# 2    tony  mackwi   32       False      88

# %%
df['lname'].sort_values()
# Out:
# 2    mackwi
# 1     vader
# 0      zena
# Name: lname, dtype: object

# %%
df2 = pd.read_csv('survey_results_public.csv', index_col = 'ResponseId')

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df2.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
df2.sort_values(by=['Country', 'ConvertedCompYearly'], ascending=[True, False], inplace=True)

# %%
df2[['Country', 'ConvertedCompYearly']].head(50)
# Out:
#                 Country  ConvertedCompYearly
# ResponseId
# 88348       Afghanistan            9203683.0
# 86039       Afghanistan              68000.0
# 1335        Afghanistan               2403.0
# 57362       Afghanistan               2288.0
# 17873       Afghanistan               1144.0
# 36049       Afghanistan                915.0
# 53322       Afghanistan                794.0
# 41679       Afghanistan                648.0
# 39427       Afghanistan                 48.0
# 37956       Afghanistan                 41.0
# 2642        Afghanistan                 33.0
# 21498       Afghanistan                  NaN
# 65293       Afghanistan                  NaN
# 33928       Afghanistan                  NaN
# 77723       Afghanistan                  NaN
# 10377       Afghanistan                  NaN
# 83821       Afghanistan                  NaN
# 73714       Afghanistan                  NaN
# 61453       Afghanistan                  NaN
# 21673       Afghanistan                  NaN
# ...

# %%
df2['ConvertedCompYearly'].nlargest(10)
# Out:
# ResponseId
# 53269    74351432.0
# 77849    73607918.0
# 66224    72714292.0
# 28122    57513831.0
# 19680    36573181.0
# 55103    17612921.0
# 80587    11000000.0
# 83680    10319366.0
# 47798     9915585.0
# 88348     9203683.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df2.nlargest(10, 'ConvertedCompYearly')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 53269       I agree                     I am a developer by profession
# 77849       I agree                     I am a developer by profession
# 66224       I agree                     I am a developer by profession
# 28122       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 55103       I agree  I am not primarily a developer, but I write co...
# 80587       I agree                     I am a developer by profession
# 83680       I agree                     I am a developer by profession
# 47798       I agree                     I am a developer by profession
# 88348       I agree                     I am a developer by profession
#
#                            Age  \
# ResponseId
# 53269          18-24 years old
# 77849          35-44 years old
# 66224          55-64 years old
# ...
