# %%
import pandas as pd
df = pd.read_csv('survey_results_public.csv', index_col = 'ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
df['ConvertedCompYearly'].head(15)
# Out:
# ResponseId
# 1          NaN
# 2     285000.0
# 3     250000.0
# 4     156000.0
# 5      23456.0
# 6      96828.0
# 7     135000.0
# 8      80000.0
# 9      64254.0
# 10         NaN
# 11         NaN
# 12     78003.0
# 13     75000.0
# 14    150000.0
# 15    187407.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 74963.0

# %%
df.describe()
# Out:
#           CompTotal       WorkExp  ConvertedCompYearly
# count  4.822500e+04  43579.000000         4.801900e+04
# mean   1.036807e+42     11.405126         1.031101e+05
# std    2.276847e+44      9.051989         6.814188e+05
# min    0.000000e+00      0.000000         1.000000e+00
# 25%    6.300000e+04      5.000000         4.390700e+04
# 50%    1.150000e+05      9.000000         7.496300e+04
# 75%    2.300000e+05     16.000000         1.216410e+05
# max    5.000000e+46     50.000000         7.435143e+07

# %%
df['ConvertedCompYearly'].count()
# Out:
# 48019

# %%
df['SOAccount'].value_counts()
# Out:
# SOAccount
# Yes                        66282
# No                         14618
# Not sure/can't remember     6952
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
df['SurveyEase']
# Out:
# ResponseId
# 1                               NaN
# 2                              Easy
# 3                              Easy
# 4                              Easy
# 5        Neither easy nor difficult
#                     ...
# 89180    Neither easy nor difficult
# 89181                          Easy
# 89182    Neither easy nor difficult
# 89183    Neither easy nor difficult
# 89184                          Easy
# Name: SurveyEase, Length: 89184, dtype: object

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
schema_df.loc[10]
# Out:
# qid                                                      QID190
# qname                                                        S2
# question      <span style="font-size:22px; font-family: aria...
# force_resp                                                False
# type                                                         DB
# selector                                                     TB
# Name: 10, dtype: object

# %%
schema_df['question']
# Out:
# 0     <div><span style="font-size:19px;"><strong>Hel...
# 1                                     Browser Meta Info
# 2     <div><span style="font-size:19px;"><strong>You...
# 3
# 4     <span style="font-size:22px; font-family: aria...
# 5     Which of the following options best describes ...
# 6                                   What is your age? *
# 7     Which of the following best describes your cur...
# 8     Which best describes your current work situation?
# 9     Which of the following best describes the code...
# 10    <span style="font-size:22px; font-family: aria...
# 11    Which of the following best describes the high...
# 12     How do you learn to code? Select all that apply.
# 13    What online resources do you use to learn to c...
# 14    What online courses or certifications do you u...
# 15    Including any education, how many years have y...
# 16    NOT including education, how many years have y...
# 17    Which of the following describes your current ...
# ...

# %%
df['SurveyEase'].value_counts()
# Out:
# SurveyEase
# Easy                          54092
# Neither easy nor difficult    31088
# Difficult                      1374
# Name: count, dtype: int64

# %%
df['SurveyEase'].value_counts(normalize=True)
# Out:
# SurveyEase
# Easy                          0.624951
# Neither easy nor difficult    0.359175
# Difficult                     0.015874
# Name: proportion, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Canada')
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 41          I agree  I am a developer by profession  18-24 years old
# 46          I agree  I am a developer by profession  25-34 years old
# 115         I agree  I am a developer by profession  18-24 years old
# 141         I agree  I am a developer by profession  45-54 years old
# 165         I agree  I am a developer by profession  18-24 years old
# ...             ...                             ...              ...
# 89121       I agree  I am a developer by profession  35-44 years old
# 89143       I agree           I am learning to code  18-24 years old
# 89149       I agree  I am a developer by profession  25-34 years old
# 89156       I agree  I am a developer by profession  25-34 years old
# 89158       I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
filt = df['Country'] == 'United States of America'
df.loc[filt]['SurveyEase'].value_counts()
# Out:
# SurveyEase
# Easy                          12714
# Neither easy nor difficult     5477
# Difficult                       180
# Name: count, dtype: int64

# %%
country_grp['SurveyEase'].value_counts(normalize = True).loc['India']
# Out:
# SurveyEase
# Easy                          0.537774
# Neither easy nor difficult    0.423905
# Difficult                     0.038321
# Name: proportion, dtype: float64

# %%
country_grp['ConvertedCompYearly'].describe().loc['Germany']
# Out:
# count    3.970000e+03
# mean     8.245748e+04
# std      5.213059e+04
# min      1.000000e+00
# 25%      5.889900e+04
# 50%      7.496300e+04
# 75%      9.638100e+04
# max      1.285075e+06
# Name: Germany, dtype: float64

# %%
country_grp['ConvertedCompYearly'].agg(['median','mean']).loc['Canada']
# Out:
# median     89222.000000
# mean      142136.677435
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['TimeSearching'].str.contains('30-60 minutes').sum()
# Out:
# 1006

# %%
country_grp['TimeSearching'].apply(lambda x: x.str.contains('30-60 minutes').value_counts(normalize = True))
# Out:
# Country
# Afghanistan  False    0.571429
#              True     0.428571
# Albania      False    0.538462
#              True     0.461538
# Algeria      False    0.541667
#                         ...
# Yemen        False    0.285714
# Zambia       True     0.583333
#              False    0.416667
# Zimbabwe     False    0.571429
#              True     0.428571
# Name: TimeSearching, Length: 321, dtype: float64
