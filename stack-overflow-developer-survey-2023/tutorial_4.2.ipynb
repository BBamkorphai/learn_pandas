# %%
import pandas as pd
df = pd.read_csv('survey_results_public.csv')
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
filt_thai = df['Country'] == "Thailand"

# %%
df[filt_thai]
# Out:
#        ResponseId     Q120                      MainBranch  \
# 1068         1069  I agree     I code primarily as a hobby
# 2033         2034  I agree  I am a developer by profession
# 2568         2569  I agree  I am a developer by profession
# 2765         2766  I agree  I am a developer by profession
# 3060         3061  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 85440       85441  I agree  I am a developer by profession
# 86382       86383  I agree           I am learning to code
# 86745       86746  I agree  I am a developer by profession
# 87318       87319  I agree  I am a developer by profession
# 88842       88843  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 1068   Under 18 years old             Not employed, and not looking for work
# 2033      18-24 years old                                Employed, full-time
# ...

# %%
filt_freq = df["Frequency_1"] == "1-2 times a week"

# %%
df[filt_thai & filt_freq]
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 2033         2034  I agree  I am a developer by profession  18-24 years old
# 7548         7549  I agree  I am a developer by profession  25-34 years old
# 8871         8872  I agree  I am a developer by profession  35-44 years old
# 8944         8945  I agree           I am learning to code  25-34 years old
# 8990         8991  I agree  I am a developer by profession  35-44 years old
# ...           ...      ...                             ...              ...
# 80374       80375  I agree  I am a developer by profession  18-24 years old
# 84472       84473  I agree  I am a developer by profession  18-24 years old
# 85440       85441  I agree  I am a developer by profession  45-54 years old
# 87318       87319  I agree  I am a developer by profession  25-34 years old
# 88842       88843  I agree  I am a developer by profession  35-44 years old
#
# ...

# %%
df.loc[filt_thai & filt_freq, 'Age']
# Out:
# 2033     18-24 years old
# 7548     25-34 years old
# 8871     35-44 years old
# 8944     25-34 years old
# 8990     35-44 years old
#               ...
# 80374    18-24 years old
# 84472    18-24 years old
# 85440    45-54 years old
# 87318    25-34 years old
# 88842    35-44 years old
# Name: Age, Length: 66, dtype: object

# %%
filt_age = df['Age'].str.contains("24", na=False)

# %%
df.loc[filt_thai & filt_freq & filt_age, 'YearsCode']
# Out:
# 2033      6
# 9539      1
# 10271     8
# 10804     3
# 17268    14
# 17277     3
# 30795     1
# 31026     6
# 80374     8
# 84472    14
# Name: YearsCode, dtype: object
